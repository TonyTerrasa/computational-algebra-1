# %% [markdown]
# # Name and Date
#
#
# Name: Stew Dent
#
#
# Date: Spring 2023

# %% [markdown]
# # Programming Mini Quiz Number 1
#
# In this mini quiz you will demonstrate your understanding of the most important programming skills we've learned so far in this unit.
#
#
#
# Please remember that outside resources are not allowed while you write your code.
#
# This assignment should take **15 minutes**.

# %% [markdown]
# ### A small hint
#
# In this mini quiz, you'll be asked to show your answers by printing them with "label text." Label text is text which allows the reader to know what they're reading when they see the output of your program. In the example below `"The length of the hypotenuse is:"` serves as the label text.

# %%
a,b = 3, 4
c = (a**2 + b**2)**0.5
print("The length of the hypotenuse is:", c)
# Out:
# The hypotenuse is: 5.0

# %% [markdown]
# ## Part 1
#
# Below, declare variables with the names and values below.
#
# | Variable  | Value  |
# |---|---|
# | term_1  |  49 |
# | term_2  |  13 |
# |  dividend | 400  |
# |  divisor | 2.5  |

# %%
term_1 = 49
term_2 = 13
dividend = 400
divisor = 2.5

# %% [markdown]
# ## Part 2
#
#
#
# 1.   Calculate the *sum* and `term_1` and `term_2` and print the answer **WITH labeling text**.

# %%
term_sum = term_1 + term_1
print("The sum of term_1 and term_2 is", term_sum)
# Out:
# The sum of term_1 and term_2 is 98

# %% [markdown]
# 2.   Calculate the *product* and `term_1` and `term_2` and print the answer **WITH labeling text**.

# %%
term_prod = term_1 * term_1
print("The product of term_1 and term_2 is", term_prod)
# Out:
# The product of term_1 and term_2 is 2401

# %% [markdown]
# 3.   Make a new variable `quotient` whose value is `dividend` divided by `divisor`. Print `quotient` **WITH labeling text**.

# %%
quotient = dividend / divisor
print("dividend divided by divisor is", quotient)
# Out:
# dividend divided by divisor is 160.0

# %% [markdown]
# 4. Find the *remainder* of `term_1` divided by `term_2` and print the answer print the answer **WITH labeling text**.

# %%
remainder = term_1 % term_2
print("The remainder of term_1 divided by term_2 is", remainder)
# Out:
# The remainder of term_1 divided by term_2 is 10
