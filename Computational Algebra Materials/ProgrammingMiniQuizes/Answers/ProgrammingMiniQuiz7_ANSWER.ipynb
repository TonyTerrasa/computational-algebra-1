# %% [markdown]
# # Name and Date
#
#
# Name: Stew Dent
#
#
# Date: Spring 2023

# %% [markdown]
# # Programming Mini Quiz Number 7
#
# In this mini quiz you will demonstrate your understanding of the most important programming skills we've learned so far in this unit.
#
#
#
# Please remember that outside resources are not allowed while you write your code.
#
# This assignment should take **20 minutes**.

# %% [markdown]
# ### A small hint
#
# In this mini quiz, you'll be asked to show your answers by printing them with "label text." Label text is text which allows the reader to know what they're reading when they see the output of your program. In the example below `"The length of the hypotenuse is:"` serves as the label text.

# %%
a,b = 3, 4
c = (a**2 + b**2)**0.5
print("The length of the hypotenuse is:", c)
# Out:
# The length of the hypotenuse is: 5.0

# %% [markdown]
# ## The Use of Python in The World
#
# Python is not just something you can use for mathematical computing. In fact, there are a lot of apps you may use everyday that use Python. One of the most commonly known of these sites in Instagram, but there are many many more<sup>1</sup>.
#
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThq0ICZDZ7AbgTOOeLsUMGKLaajUgWY7yNBQ&usqp=CAU)
#
# Image from Den Delimarsky<sup>2</sup>

# %% [markdown]
# ## Part 1: Mathstagram User
# Imagine you are building a new social media platform called *Mathstagram* where people can watch math videos and share them with their friends.
#
# 1. Make a `MathstagramUser` class with its constructor. Necessary instance variables for every user (and therefore passed into the constructor) will be:
# *   Username (`handle`)
# *   Email Address (`email`)

# %%
class MathstagramUser: 
  def __init__(self, handle, email): 
    self.handle = handle
    self.email = email
    self.time_watched = 0
  
  # don't forget the self!
  def watch_video(self, video_length):
    self.time_watched += video_length
  
  # don't forget the self!
  def request_usage(self):
    return f"So far, you've watched {self.time_watched} minutes of videos on Mathstagram"

# %% [markdown]
# ## Part 2: Mathstagram Usage
#
# Unlike other social media platforms, the goal of Mathstagram is to promote healthy use of its platform. To do this, the platform keeps track of how the user spends on the platform.
#
# 1. Add to your class constructor an instance variable called `time_watched` which starts at `0` for everyone.
# 2. Add to your class above a function called `watch_video` which takes as a parameter the the length of the video in minutes and adds that to the `time_watched` instance variable.
# 3. Add to your class above a function called `request_usage` which takes no arguments but returns a message (as a `str`) which tells the user the total time they've watched.

# %%
# demonstration not necessary, but helpful to make sure it's working

jose = MathstagramUser("mathyjose", "jose2000@gmail.com")
cris = MathstagramUser("cristhemathwhiz", "crisycris2010@gmail.com")

# make a change to jose
print(jose.request_usage())
jose.watch_video(1.2)
print(jose.request_usage())

# make some more changes to jose
jose.watch_video(5.2)
jose.watch_video(0.4)
print(jose.request_usage())

# should still be 0
print(cris.request_usage())
# Out:
# So far, you've watched 0 minutes of videos on Mathstagram
# So far, you've watched 1.2 minutes of videos on Mathstagram
# So far, you've watched 6.800000000000001 minutes of videos on Mathstagram
# So far, you've watched 0 minutes of videos on Mathstagram

# %% [markdown]
# ## References
#
# <sup>1</sup>[10 Famous Websites Built Using Python](https://learn.onemonth.com/10-famous-websites-built-using-python/#:~:text=Instagram,is%20written%20entirely%20in%20Python.)
#
# <sup>2</sup>[Authenticating With Instagram Without The Browser](https://den.dev/blog/instagram-python/)
