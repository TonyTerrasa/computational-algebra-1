# %% [markdown]
# Name:
#
#
# Date:

# %% [markdown]
# # Lab 4
#
# In this lab, we're going to be used the programming and the math skills we've been using in class to determine where we want to live!

# %% [markdown]
# # User Input (~ Reprise ~)
#
# Remember in lab 2 we looked at the making small programs that took user input.
#
# <blockquote>
# <em>
# First, let's review how to take user input. To recieve use input, you use the `input` function. For example, see the simple program below.
#
# ```
# current_year = 2023
# birth_year = input("What year were you born? ")
# birth_year = int(birth_year)
# year_difference = current_year - birth_year
# print("You were born", year_difference, "years ago")
# ```
# </em>
# </blockquote>
#
# Today, we're going to expand this with more options and more functions.

# %% [markdown]
# For example, let's say we also want to tell the person what **generation** they are a part of. Now generation boundaries are widely debated and felxible but they are roughly:
#
# | Generation  | Birth Years  |
# |---|---|
# | The Greatest Generation  |  1901-1924 |
# | The Silent Generation  |  1925-1945 |
# |  Baby Boomer | 1946-1964  |
# |  Generation X | 1965-1979  |
# |  Millennials | 1980-1994  |
# |  Generation Z | 1995-2012  |
# |  Gen Alpha | 2013 – 2025  |
#
# Info from Caregivers of America<sup>1</sup>
#
#
# So, let's say we want to tell people what generation they are as well as how many years ago they were born. Our first version might look something like this:

# %%
current_year = 2023
birth_year = input("What year were you born? ")
birth_year = int(birth_year)

if 1901 <= birth_year <= 1924:
  generation = "The Greatest Generation"
elif 1925 <= birth_year <= 1945: 
  generation = "The Silent Generation"
elif 1946 <= birth_year <= 1964: 
  generation = "The Baby Boomers"
elif 1965 <= birth_year <= 1979: 
  generation = "Generation X"
elif 1980 <= birth_year <= 1994: 
  generation = "The Millennials"
elif 1995 <= birth_year <= 2012: 
  generation = "Generation Z"
elif 2013 <= birth_year: 
  generation = "Generation Alpha"
else: 
  generation = "no generation"

year_difference = current_year - birth_year
print("You were born", year_difference, "years ago, which means you're part of", generation)
# Out:
# What year were you born? 1969
# You were born 54 years ago, which means you're part of Generation X

# %% [markdown]
# This definitely works, but when you look at this big set of `if` statements, it's easy to lose yourself. So, what if we could write something like:
# ```
# current_year = 2023
# birth_year = input("What year were you born? ")
# birth_year = int(birth_year)
# generation = find_generation()
# year_difference = current_year - birth_year
# print("You were born", year_difference, "years ago, which means you're part of", generation)
# ```
#
# Look how much cleaner that is! Well, as you know this is exactly the type of thing that a function can help us with. For example, we could write out script like this:

# %%
def find_generation(year): 
  """Function that finds the generation of a given birth year"""
  if 1901 <= year <= 1924:
    generation = "The Greatest Generation"
  elif 1925 <= year <= 1945: 
    generation = "The Silent Generation"
  elif 1946 <= year <= 1964: 
    generation = "The Baby Boomers"
  elif 1965 <= year <= 1979: 
    generation = "Generation X"
  elif 1980 <= year <= 1994: 
    generation = "The Millennials"
  elif 1995 <= year <= 2012: 
    generation = "Generation Z"
  elif 2013 <= year: 
    generation = "Generation Alpha"
  else: 
    generation = "no generation"
  return generation

# Script for
current_year = 2023
birth_year = input("What year were you born? ")
birth_year = int(birth_year)
generation = find_generation(birth_year)
year_difference = current_year - birth_year
print("You were born", year_difference, "years ago, which means you're part of", generation)
# Out:
# What year were you born? 2004
# You were born 19 years ago, which means you're part of Generation Z

# %% [markdown]
# # Your turn
#
# Now, expand your script from Lab 2. In doing so you should:
# - include some logic (an `if` statement of some kind)
# - break at least one part of your script into a function
#
#
# As you do your project, answer these questions below.
# - What new functionality did you choose to add? Why do you find that one interesting?
# - Why did you choose to put the part(s) that you did in a separate function(s)? Did it make the final script easier to read or make it more confusing? Why?
# - Try a variety of inputs. Did it give the answers that you expected?

# %%
# Your code goes here

# %% [markdown]
# # Your Response
#
# Double click here to add you response. Press Shift+Enter when done (just like running a code cell).
#
# --------------------

# %% [markdown]
# # References and Notes
# <sup>1</sup> [2022 Generation Names Explained](https://caregiversofamerica.com/2022-generation-names-explained/)
