# %% [markdown]
# Name:
#
#
# Date:

# %% [markdown]
# # Lab 7
#
# In this lab, we're going to be combine a lot of the programming and mathematics skills that we've learned up until this point! This is going to be a big one :)

# %% [markdown]
# ## Quadratic Class
#
# In this lab, your first job is to make a `Quadratic` class. This class will be used to solve and represent quadratic equations.
#
# This class should have:
#
# 1. A *constructor* which takes arguments `a`, `b`, and `c` and stores them as instance variables. These will correspond to the form of the quadratic $y = ax^2 + bx + c$.
#
# 2. An `standard_form(self)` function which should retun a `str` that tells the user what the equation stored is in standard form (e.g. `"This Quadratic in stard form is 5x^2 + 6x + 9"`)
#
# 3. An `vertex_form(self)` function which should retun a `str` that tells the user what the equation stored is in vertex form (e.g. `"This Quadratic in vertex form is is 5(x-2)^2 + 9"`)
#
# 4. An `factored_form(self)` function which should retun a `str` that tells the user what the equation stored is in factored form (e.g. `"This Quadratic in factored form is is (x-2)(x+5)"`)
#
# 5. A `find_zero(self)` function which finds the zero of this `Quadratic` using `a`, `b`, `c`, representation. It should solve the equation $ax^2 + bx + c = 0$. You will probably want to use the quadratic formula for this equation.
#
# 6. A `solve_for_x(self, y)` function which finds the value(s) of `x` for a given `y`. This should be done. You may want to use your `find_zero` funciton to solve thsi problem
#
# 7. A `graph(self, start=0, end=10)` function which graphs and shows the function stored in the `Quadratic` from $ x= $ `start` to $ x= $ `end`

# %%
class Quadratic: 
  # your code goes here

# %% [markdown]
# # Application
#
# Now, go back to the situation you used in Lab 6 to model a quadratic equation.
#
#
# 1. Write the equation in standard form:
# $$y = ax^2 + bx + c$$
# And make a `Quadratic` instance of this equation.

# %%
# Your code here

# %% [markdown]
# 2. Test that things are working with your class by:
# - printing out the equation of your `Quadratic` in vertex, factored, and standard form and comparing that to your manual calculations
# - graphing your `Quadratic`

# %% [markdown]
# 3. Use your class to solve for the `x` of various values of `y`. What do each of these (x,y) pairs this mean in the context of your situation?

# %%
# Your code here

# %% [markdown]
# #### Your Response
#
# Double click here to add you response. Press Shift+Enter when done (just like running a code cell).
#
# --------------------

# %% [markdown]
# 4. Add one more function to your `Quadratic` class. Below, explain why it's helpful and show an example of how you would use it.

# %%
# show how you would use this new function

# %% [markdown]
# # Your Response
#
# Double click here to add you response. Press Shift+Enter when done (just like running a code cell).
#
# --------------------
