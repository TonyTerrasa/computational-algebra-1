# %% [markdown]
# # Solutions

# %% [markdown]
# ## Warm-up
#
# Turn the following data into two line graphs and one scatter plot (on a piece of paper). Which one is better for determining the correlation between the two variables? How would you classify the correlation between these two variables?
#
# | Hours Slept | Test Score |
# |---|---|
# | 5 | 70 |
# | 5.5 | 73 |
# | 6 | 75 |
# | 6.1 | 80 |
# | 8 | 85 |

# %% [markdown]
# Scatter plot is better for checking the correlation because it plots each of the data points against eachother. Line graphs are better for looking at single streams of data over time. Or, if you have a series of two-variable data where order is important.
#
# However, scatter is what best shows us the relationship between these data. In this case, there is a strong positive relationship between our two points.
#
# There are graphs made by matplotlib at the top of this file for the data used.

# %%
import matplotlib.pyplot as plt
hours = [5, 5.5, 6, 6.1, 8]
scores = [70, 73, 75, 80, 85]

fig, axs = plt.subplots(1, 3)

axs[0].plot(hours)
axs[0].set_title("Hours Slept")
axs[1].plot(scores)
axs[1].set_title("Scores")
axs[2].scatter(hours, scores)
axs[2].set_title("Hours Slept versus Test Scores")
fig.tight_layout()
plt.show()

# %% [markdown]
# # Part 1: Plotting with Matplotlib
#
# To graph using Python we're going to need a library made for "plotting" or making graphs. In Python, one of the most popular is Matplotlib. It's a library which has its roots in Matlab, another important (though expensive) programming language for scientific computing.
#
# First, we're going to have to import Matplotlib. The most common way to do this is to import it `as plt` this means that when we want to use it later, all we need to do is use `plt` instead of the long name for the package.
#
# ```
# # the import
# import matplotlib.pyplot as plt
#
# # make a graph
# plt.plot([1,2,3,4,5])
#
# # display the graph on the screen
# plt.show()
# ```
#  But let's not get too far ahead of ourselves.
#
#  1. First, complete the script below so that we have the right import

# %%
# YOUR CODE HERE
import matplotlib.pyplot as plt

# make a graph 
plt.plot([1,4,5,6], [5,6,8,9])

# display the graph on the screen
plt.show()

# %% [markdown]
# ### Line graphs
#
# The scripts we've seen until now have three main parts:
# 1.   Importing Matplotlib (which we now know how to do)
# 2.   CREATING the graph
# 3.   Showing the graph on screen
#
# Note that the last step is necessary because sometimes we might make quite complicated graphics with multiple graphs, and we don't want to display it until all the graphics are complete.
#
#
# The simplist plot that you can make in matplotlib is a line graph which can be made using `plt.plot(data)` where `data` is a list. This plots the values in `data` as the y axis values and the x axis values will simply be `1, 2, 3, 4, ...`.
#
#
# 2. Make and show a plot of the given list.

# %%
hours_slept = [5, 5.5, 5.8, 6, 6.1, 6.3, 6.6, 6.7, 7.2, 7.4, 7.7, 7.8, 7.9, 8]

# your code goes here
import matplotlib.pyplot as plt
plt.plot(hours_slept)
plt.show()

# %% [markdown]
# However, we can also make scatter plots using the command `plt.scatter(x_data, y_data)` where the data is treated like a set of x-y pairs as if the data were:
#
# | x | y |
# |---|---|
# | `x_data[0]` | `y_data[0]` |
# | `x_data[1]` | `y_data[1]` |
# | `x_data[2]` | `y_data[2]` |
# | ... | ... |
#
#
# For this reason `x_data` and `y_data` must have the same length.
#
# So, let's look at an example of making a scatter plot:
# ```
# hours = [5, 5.5, 6, 6.1, 8]
# scores = [70, 73, 75, 80, 85]
#
# # import
# import matplotlib.pyplot as plt
#
# # make the scatter plot
# plt.scatter(hours, scores)
#
# # display the graph
# plt.show()
# ```

# %% [markdown]
# 3. Your turn! Make two scatter plots:
# - one of the data with `hours_slept` as the x and `scores_given` as y
# - one of the data with `scores_given` as the x and `hours_slept` as the y

# %%
hours_slept = [5, 5.5, 5.8, 6, 6.1, 6.3, 6.6, 6.7, 7.2, 7.4, 7.7, 7.8, 7.9, 8]
scores_given = [58, 65, 69, 68, 70, 75, 81, 80, 84, 85, 97, 97, 91, 98]

# Your Code Here (Graph 1)
import matplotlib.pyplot as plt
plt.scatter(hours_slept, scores_given)
plt.show()

# %%
hours_slept = [5, 5.5, 5.8, 6, 6.1, 6.3, 6.6, 6.7, 7.2, 7.4, 7.7, 7.8, 7.9, 8]
scores_given = [58, 65, 69, 68, 70, 75, 81, 80, 84, 85, 97, 97, 91, 98]

# Your Code Here (Graph 2)
import matplotlib.pyplot as plt
plt.scatter(scores_given, hours_slept)
plt.show()

# %% [markdown]
# Now, last thing is that's always super important to add a title to your graphics. This can be done with the `plt.title("Awesome Title")` function. See the example below:
#
# ```
# hours = [5, 5.5, 6, 6.1, 8]
# scores = [70, 73, 75, 80, 85]
#
# # import
# import matplotlib.pyplot as plt
#
# # make the scatter plot
# plt.scatter(hours, scores)
#
# # add a title and axis labels
# plt.title("Hours Slept Versus Score Given")
# plt.xlabel("Hours Slept")
# plt.ylabel("Score Given")
#
# # display the graph
# plt.show()
# ```
#
# 4. Add titles and axis labels to YOUR graphs above.

# %%
hours_slept = [5, 5.5, 5.8, 6, 6.1, 6.3, 6.6, 6.7, 7.2, 7.4, 7.7, 7.8, 7.9, 8]
scores_given = [58, 65, 69, 68, 70, 75, 81, 80, 84, 85, 97, 97, 91, 98]

# Your Code Here (Graph 2)
import matplotlib.pyplot as plt
plt.scatter(scores_given, hours_slept)
plt.title("Scores Versus Hours Slept")
plt.xlabel("Hours Slept")
plt.ylabel("Test Scores")
plt.show()

# %% [markdown]
# # Part 2: Problems

# %% [markdown]
# Below you have height (inches) and weight (pounds) data of 200 people of 18 years of age <sup>1</sup>.
#
# 1. Make a scatter plot (don't forget a title and axis labels) of the data.
# 2. Comment on the correlation. What does this mean?

# %%
height = [65.78331, 71.51521, 69.39874, 68.2166, 67.78781, 68.69784, 69.80204, 70.01472, 67.90265, 66.78236, 66.48769, 67.62333, 68.30248, 67.11656, 68.27967, 71.0916, 66.461, 68.64927, 71.23033, 67.13118, 67.83379, 68.87881, 63.48115, 68.42187, 67.62804, 67.20864, 70.84235, 67.49434, 66.53401, 65.44098, 69.5233, 65.8132, 67.8163, 70.59505, 71.80484, 69.20613, 66.80368, 67.65893, 67.80701, 64.04535, 68.57463, 65.18357, 69.65814, 67.96731, 65.98088, 68.67249, 66.88088, 67.69868, 69.82117, 69.08817, 69.91479, 67.33182, 70.26939, 69.10344, 65.38356, 70.18447, 70.40617, 66.54376, 66.36418, 67.537, 66.50418, 68.99958, 68.30355, 67.01255, 70.80592, 68.21951, 69.05914, 67.73103, 67.21568, 67.36763, 65.27033, 70.84278, 69.92442, 64.28508, 68.2452, 66.35708, 68.36275, 65.4769, 69.71947, 67.72554, 68.63941, 66.78405, 70.05147, 66.27848, 69.20198, 69.13481, 67.36436, 70.09297, 70.1766, 68.22556, 68.12932, 70.24256, 71.48752, 69.20477, 70.06306, 70.55703, 66.28644, 63.42577, 66.76711, 68.88741, 64.87434, 67.09272, 68.34761, 65.61073, 67.75551, 68.0212,
import matplotlib.pyplot as plt
plt.scatter(height, weight)
plt.title("Height and Weight of 200 Adults")
plt.xlabel("Height (in)")
plt.ylabel("Weight (lb)")
plt.show()

# %% [markdown]
# #### Your Response Here

# %% [markdown]
# There seems to be a medium-strong positive correlation between height and weight, meaning as height increases, weight also tends to increase. This makes sense because there is naturally more to people who are taller. They have more bones, more skin, more water, bigger features, all of which would contribute to a heigher weight.

# %% [markdown]
# Now, let's look at search data. Search data tells us how much people searched (e.g. with Google) for specific things. In this case, we're looking at health search data <sup>2</sup>. Each of these lists tells us *how much people searched for a given term* over many places in the United States.

# %%
cardiovascular_searches_2016 = [38, 41, 33, 59, 42, 48, 44, 45, 42, 54, 43, 39, 54, 50, 41, 37, 38, 34, 48, 41, 70, 55, 72, 37, 45, 67, 39, 50, 47, 51, 54, 56, 28, 46, 53, 41, 33, 52, 36, 49, 32, 41, 39, 56, 53, 47, 60, 41, 44, 35, 38, 51, 48, 58, 39, 44, 72, 39, 16, 33, 49, 66, 44, 41, 30, 52, 39, 51, 38, 46, 52, 52, 38, 53, 39, 52, 69, 0, 68, 45, 97, 39, 35, 33, 42, 41, 53, 61, 44, 45, 39, 38, 100, 59, 46, 52, 46, 44, 42, 50, 41, 39, 55, 33, 32, 57, 75, 39, 68, 34, 34, 33, 46, 47, 57, 77, 90, 40, 89, 49, 43, 73, 61, 39, 45, 50, 35, 40, 46, 34, 42, 44, 50, 35, 38, 35, 54, 45, 46, 43, 45, 58, 50, 22, 52, 44, 45, 88, 41, 58, 60, 58, 87, 67, 52, 67, 38, 51, 56, 50, 42, 59, 60, 39, 36, 45, 43, 0, 40, 36, 33, 54, 28, 32, 38, 38, 48, 36, 42, 33, 31, 63, 17, 26, 37, 54, 43, 45, 40, 0, 52, 47, 29, 39, 29, 36, 39, 39, 36, 28, 39, 43, 50, 32, 37, 35, 38, 55, 36, 36]
obesity_searches_2016 = [49, 49, 70, 51, 52, 43, 53, 46, 50, 55, 48, 53, 61, 57, 50, 46, 46, 45, 59, 47, 55, 55, 68, 68, 43, 56, 64, 54, 43, 46, 60, 51, 45, 58, 42, 50, 46, 53, 52, 41, 52, 66, 44, 73, 49, 58, 75, 54, 47, 61, 51, 55, 91, 51, 53, 74, 57, 41, 49, 57, 58, 43, 48, 54, 49, 47, 44, 71, 42, 37, 54, 72, 36, 49, 44, 62, 71, 0, 70, 54, 93, 48, 35, 50, 49, 45, 50, 100, 65, 40, 44, 46, 87, 44, 51, 49, 51, 41, 55, 55, 37, 51, 81, 0, 48, 54, 49, 71, 54, 35, 35, 40, 50, 69, 58, 52, 57, 43, 38, 33, 54, 85, 75, 49, 51, 60, 49, 31, 41, 50, 49, 50, 48, 53, 45, 37, 66, 55, 68, 43, 60, 50, 40, 34, 38, 26, 56, 46, 68, 52, 51, 47, 60, 58, 48, 65, 68, 67, 68, 48, 58, 99, 0, 45, 55, 61, 47, 0, 34, 46, 36, 50, 61, 43, 50, 50, 68, 48, 54, 51, 46, 58, 64, 47, 52, 55, 54, 60, 47, 0, 52, 75, 46, 49, 38, 45, 50, 47, 52, 43, 53, 41, 52, 64, 38, 54, 48, 64, 63, 52]

cardiovascular_searches_2017 = [37, 34, 24, 38, 35, 38, 37, 32, 35, 36, 35, 31, 42, 47, 32, 30, 34, 30, 39, 35, 50, 40, 50, 30, 37, 50, 33, 39, 40, 39, 43, 39, 24, 36, 43, 34, 23, 33, 29, 40, 30, 29, 32, 42, 44, 41, 41, 35, 33, 29, 34, 56, 22, 34, 24, 37, 52, 24, 29, 34, 40, 52, 35, 41, 13, 38, 31, 30, 30, 35, 45, 44, 27, 43, 28, 35, 36, 0, 55, 41, 73, 16, 38, 28, 30, 32, 25, 41, 35, 24, 33, 28, 70, 48, 37, 44, 38, 35, 29, 46, 35, 39, 41, 31, 23, 44, 64, 33, 50, 25, 34, 30, 37, 42, 49, 82, 77, 36, 78, 47, 42, 45, 56, 36, 32, 36, 27, 39, 31, 29, 36, 32, 32, 28, 25, 29, 47, 34, 29, 38, 33, 44, 39, 22, 40, 45, 33, 78, 31, 46, 46, 30, 100, 51, 44, 43, 31, 37, 47, 36, 32, 34, 31, 19, 28, 14, 31, 0, 44, 28, 28, 46, 25, 31, 31, 28, 31, 26, 33, 28, 27, 52, 10, 27, 31, 57, 19, 27, 29, 0, 44, 31, 35, 33, 27, 29, 25, 30, 23, 22, 31, 26, 37, 27, 31, 24, 29, 42, 38, 33]
obesity_searches_2017 = [47, 52, 61, 41, 56, 45, 58, 44, 52, 49, 51, 59, 67, 63, 52, 49, 57, 47, 52, 45, 61, 48, 62, 59, 48, 47, 58, 58, 49, 52, 54, 50, 48, 62, 41, 49, 45, 78, 58, 45, 48, 67, 49, 72, 52, 58, 73, 57, 49, 46, 54, 63, 58, 43, 43, 62, 56, 41, 37, 61, 58, 47, 51, 58, 43, 45, 48, 69, 42, 42, 62, 65, 49, 39, 50, 54, 82, 0, 77, 53, 94, 42, 50, 44, 42, 49, 52, 86, 61, 50, 48, 37, 100, 38, 53, 50, 56, 44, 45, 50, 39, 60, 81, 0, 45, 45, 49, 62, 54, 32, 38, 43, 56, 72, 52, 53, 49, 44, 41, 39, 37, 86, 77, 51, 49, 66, 51, 29, 31, 51, 50, 53, 31, 55, 47, 52, 56, 53, 66, 49, 60, 51, 46, 47, 37, 35, 58, 52, 82, 59, 47, 51, 43, 57, 67, 72, 60, 57, 61, 66, 52, 67, 0, 50, 51, 51, 37, 0, 40, 50, 42, 50, 61, 40, 36, 54, 71, 47, 47, 46, 64, 53, 46, 45, 54, 48, 56, 55, 49, 0, 51, 86, 47, 53, 47, 45, 48, 54, 40, 46, 58, 50, 56, 64, 42, 53, 55, 63, 62, 53]

# %% [markdown]
# 4. First, predict, which will have the strongest correlations? Which will have the lowest? Why?
# - obesity searches in 2016 with cardiovascular disease searches in 2016
# - obesity searches in 2017 with cardiovascular disease searches in 2017
# - obesity searches in 2016 with obesity searches in 2017
# - cardiovascular disease searches in 2016 with cardiovascular disease searches in 2017

# %% [markdown]
# ### Your Response

# %% [markdown]
# (your prediction)

# %% [markdown]
# 5. Okay, now in the space below, make scatter plots to show the relationships between each of the data pairs above. Were you guesses correct? Why or why not?

# %%
# These graphs are made all within the same figure to make it easier to see for 
# students and teachers, but students were simply expected to make 4 different
# graphics using plt.scatter()

import matplotlib.pyplot as plt
fig, axes = plt.subplots(2,2)

# obestity 2016 with cardiovascular 2016
axes[0, 0].scatter(cardiovascular_searches_2016, obesity_searches_2016)
axes[0, 0].set_xlabel("CV 2016")
axes[0, 0].set_ylabel("OB 2016")

# obestity 2017 with cardiovascular 2017
axes[0, 1].scatter(cardiovascular_searches_2017, obesity_searches_2017)
axes[0, 1].set_xlabel("CV 2017")
axes[0, 1].set_ylabel("OB 2017")

# obestity 2016 with obesity 2017
axes[1, 0].scatter(obesity_searches_2016, obesity_searches_2017)
axes[1, 0].set_xlabel("OB 2016")
axes[1, 0].set_ylabel("OB 2017")

# cardiovascular 2016 with cardiovascular 2017
axes[1, 1].scatter(cardiovascular_searches_2016, cardiovascular_searches_2017)
axes[1, 1].set_xlabel("CV 2016")
axes[1, 1].set_ylabel("CV 2017")

fig.suptitle("Search Data: Cardiovascular (CV) and Obesity (OB)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Your Response Here

# %% [markdown]
# (your opinion of whether or not your guess was correct)

# %% [markdown]
# # Bonus Finding the correlation coefficient with Python
#
# Luckily Python has several packages for doing scientific computing. One of them is called numpy, which we will learn a lot about in the future. To find the correlation coefficient, you need something like the following code:
#
# ```
# height = [65.78331, 71.51521, 69.39874]
# weight = [112.9925, 136.4873, 153.0269]
# from numpy import corrcoef
# R = corrcoef(height, weight)[0,1]
# print(R)
# ```
#
# Use the code above to calculate the correlation coefficient for the data sets we used today. Was your prediction of the correlation correct?

# %%
height = [65.78331, 71.51521, 69.39874, 68.2166, 67.78781, 68.69784, 69.80204, 70.01472, 67.90265, 66.78236, 66.48769, 67.62333, 68.30248, 67.11656, 68.27967, 71.0916, 66.461, 68.64927, 71.23033, 67.13118, 67.83379, 68.87881, 63.48115, 68.42187, 67.62804, 67.20864, 70.84235, 67.49434, 66.53401, 65.44098, 69.5233, 65.8132, 67.8163, 70.59505, 71.80484, 69.20613, 66.80368, 67.65893, 67.80701, 64.04535, 68.57463, 65.18357, 69.65814, 67.96731, 65.98088, 68.67249, 66.88088, 67.69868, 69.82117, 69.08817, 69.91479, 67.33182, 70.26939, 69.10344, 65.38356, 70.18447, 70.40617, 66.54376, 66.36418, 67.537, 66.50418, 68.99958, 68.30355, 67.01255, 70.80592, 68.21951, 69.05914, 67.73103, 67.21568, 67.36763, 65.27033, 70.84278, 69.92442, 64.28508, 68.2452, 66.35708, 68.36275, 65.4769, 69.71947, 67.72554, 68.63941, 66.78405, 70.05147, 66.27848, 69.20198, 69.13481, 67.36436, 70.09297, 70.1766, 68.22556, 68.12932, 70.24256, 71.48752, 69.20477, 70.06306, 70.55703, 66.28644, 63.42577, 66.76711, 68.88741, 64.87434, 67.09272, 68.34761, 65.61073, 67.75551, 68.0212, 67.66193, 66.3146, 69.43706, 63.83624, 67.72277, 70.05098, 70.18602, 65.94588, 70.007, 68.61129, 68.80817, 69.76212, 65.45539, 68.82534, 65.8003, 67.21474, 69.42021, 68.94396, 67.9
 30, 32, 25, 41, 35, 24, 33, 28, 70, 48, 37, 44, 38, 35, 29, 46, 35, 39, 41, 31, 23, 44, 64, 33, 50, 25, 34, 30, 37, 42, 49, 82, 77, 36, 78, 47, 42, 45, 56, 36, 32, 36, 27, 39, 31, 29, 36, 32, 32, 28, 25, 29, 47, 34, 29, 38, 33, 44, 39, 22, 40, 45, 33, 78, 31, 46, 46, 30, 100, 51, 44, 43, 31, 37, 47, 36, 32, 34, 31, 19, 28, 14, 31, 0, 44, 28, 28, 46, 25, 31, 31, 28, 31, 26, 33, 28, 27, 52, 10, 27, 31, 57, 19, 27, 29, 0, 44, 31, 35, 33, 27, 29, 25, 30, 23, 22, 31, 26, 37, 27, 31, 24, 29, 42, 38, 33]
obesity_searches_2017 = [47, 52, 61, 41, 56, 45, 58, 44, 52, 49, 51, 59, 67, 63, 52, 49, 57, 47, 52, 45, 61, 48, 62, 59, 48, 47, 58, 58, 49, 52, 54, 50, 48, 62, 41, 49, 45, 78, 58, 45, 48, 67, 49, 72, 52, 58, 73, 57, 49, 46, 54, 63, 58, 43, 43, 62, 56, 41, 37, 61, 58, 47, 51, 58, 43, 45, 48, 69, 42, 42, 62, 65, 49, 39, 50, 54, 82, 0, 77, 53, 94, 42, 50, 44, 42, 49, 52, 86, 61, 50, 48, 37, 100, 38, 53, 50, 56, 44, 45, 50, 39, 60, 81, 0, 45, 45, 49, 62, 54, 32, 38, 43, 56, 72, 52, 53, 49, 44, 41, 39, 37, 86, 77, 51, 49, 66, 51, 29, 31, 51, 50, 53, 31, 55, 47, 52, 56, 53, 66, 49, 60, 51, 46, 47, 37, 35, 58, 52, 82, 59, 47, 51, 43, 57, 67, 72, 60, 57, 61, 66, 52, 67, 0, 50, 51, 51, 37, 0, 40, 50, 42, 50, 61, 40, 36, 54, 71, 47, 47, 46, 64, 53, 46, 45, 54, 48, 56, 55, 49, 0, 51, 86, 47, 53, 47, 45, 48, 54, 40, 46, 58, 50, 56, 64, 42, 53, 55, 63, 62, 53]


from numpy import corrcoef


print("Correlation Coefficient height and weight",  corrcoef(height, weight)[0,1])
print("Correlation Coefficient CV 2016 and OB 2016",  corrcoef(cardiovascular_searches_2016, obesity_searches_2016)[0,1])
print("Correlation Coefficient CV 2017 and OB 2017",  corrcoef(cardiovascular_searches_2017, obesity_searches_2017)[0,1])
print("Correlation Coefficient OB 2016 and OB 2017",  corrcoef(obesity_searches_2016, obesity_searches_2017)[0,1])
print("Correlation Coefficient CV 2016 and CV 2017",  corrcoef(cardiovascular_searches_2016, cardiovascular_searches_2017)[0,1])
# Out:
# Correlation Coefficient height and weight 0.5567724259793423
# Correlation Coefficient CV 2016 and OB 2016 0.45634909485314584
# Correlation Coefficient CV 2017 and OB 2017 0.3313901943837687
# Correlation Coefficient OB 2016 and OB 2017 0.8533009315518301
# Correlation Coefficient CV 2016 and CV 2017 0.8538673851936796

# %% [markdown]
# # References
#
# <sup>1</sup> [Height and Weight Data from Kaggle](https://www.kaggle.com/datasets/burnoutminer/heights-and-weights-dataset)
#
# <sup>2</sup> [Health Search Data from Kaggle](https://www.kaggle.com/datasets/GoogleNewsLab/health-searches-us-county)
